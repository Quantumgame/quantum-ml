# %%
import k_means 
reload(k_means)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
n_dots = 2
X = k_means.init_dots(500,n_dots)
plt.scatter(X[:,0],X[:,1])

# %%
reload(k_means)
K = 5
(mu,centers) = k_means.find_centers(X,K)
for i in range(K):
    #colors = np.ones(len(centers[i]))*1.0*i/K+200
    plt.scatter(np.array(centers[i])[:,0],np.array(centers[i])[:,1])

# %% [markdown]
# cen = np.array(centers[0])
